# %% [markdown]
# # LISTS — Coding Interview Practice
#
# 10 algorithm-style questions (5 Easy, 5 Medium) focused on **lists**.
#
# Use the empty code cells to write your solution and run tests.

# %% [markdown]
# ---
# ## Easy (5 Questions)
# ---

# %% [markdown]
# ### Question 1: Find Maximum and Minimum in a List
#
# **Difficulty:** Easy
# **Data structure:** Lists
#
# **Problem:** Given a list of integers, return a tuple `(min, max)`. Do not use built-in `min()`/`max()` — implement with a single pass.
#
# **Example Input:** `[3, 1, 4, 1, 5]`
# **Example Output:** `(1, 5)`
#
# **Constraints:** 1 ≤ len(nums) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def find_min_max(nums: list) -> tuple:
    # Your code here
    pass

# Test
assert find_min_max([3, 1, 4, 1, 5]) == (1, 5)
assert find_min_max([7]) == (7, 7)

# %% [markdown]
# ### Question 2: Sum of List Elements
#
# **Difficulty:** Easy
# **Data structure:** Lists
#
# **Problem:** Given a list of numbers, return the sum. Implement with a loop (no built-in `sum()`).
#
# **Example Input:** `[1, 2, 3, 4, 5]`
# **Example Output:** `15`
#
# **Constraints:** 0 ≤ len(nums) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def list_sum(nums: list) -> float:
    # Your code here
    pass

# Test
assert list_sum([1, 2, 3, 4, 5]) == 15
assert list_sum([]) == 0

# %% [markdown]
# ### Question 3: Remove All Occurrences of a Value
#
# **Difficulty:** Easy
# **Data structure:** Lists
#
# **Problem:** Given a list and a value, return a new list with all occurrences of that value removed.
#
# **Example Input:** `nums = [1, 2, 3, 2, 4, 2]`, `val = 2`
# **Example Output:** `[1, 3, 4]`
#
# **Constraints:** 0 ≤ len(nums) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def remove_all(nums: list, val) -> list:
    # Your code here
    pass

# Test
assert remove_all([1, 2, 3, 2, 4, 2], 2) == [1, 3, 4]
assert remove_all([1, 1, 1], 1) == []

# %% [markdown]
# ### Question 4: Count Elements Equal to a Target
#
# **Difficulty:** Easy
# **Data structure:** Lists
#
# **Problem:** Given a list and a target value, return how many elements equal the target.
#
# **Example Input:** `nums = [1, 2, 2, 3, 2, 4]`, `target = 2`
# **Example Output:** `3`
#
# **Constraints:** 0 ≤ len(nums) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def count_target(nums: list, target) -> int:
    # Your code here
    pass

# Test
assert count_target([1, 2, 2, 3, 2, 4], 2) == 3
assert count_target([], 5) == 0

# %% [markdown]
# ### Question 5: Merge Two Sorted Lists
#
# **Difficulty:** Easy
# **Data structure:** Lists (basic traversal)
#
# **Problem:** Given two sorted lists of integers, merge them into one sorted list. Do not use built-in sort on the merged list — merge in O(n+m) using two pointers.
#
# **Example Input:** `[1, 3, 5]`, `[2, 4, 6]`
# **Example Output:** `[1, 2, 3, 4, 5, 6]`
#
# **Constraints:** 0 ≤ len(list1), len(list2) ≤ 10^4
# **Expected Time Complexity:** O(n + m)

# %%
def merge_sorted_lists(list1: list, list2: list) -> list:
    # Your code here
    pass

# Test
assert merge_sorted_lists([1, 3, 5], [2, 4, 6]) == [1, 2, 3, 4, 5, 6]
assert merge_sorted_lists([], [1, 2]) == [1, 2]

# %% [markdown]
# ---
# ## Medium (5 Questions)
# ---

# %% [markdown]
# ### Question 6: Two Sum
#
# **Difficulty:** Medium
# **Data structure:** Lists (efficient lookup with dict/set)
#
# **Problem:** Given a list of integers and a target, return indices of two numbers that add up to target. Assume exactly one solution exists. Do not use the same element twice.
#
# **Example Input:** `nums = [2, 7, 11, 15]`, `target = 9`
# **Example Output:** `[0, 1]`
#
# **Constraints:** 2 ≤ len(nums) ≤ 10^4
# **Expected Time Complexity:** O(n)

# %%
def two_sum(nums: list, target: int) -> list:
    # Your code here
    pass

# Test
assert sorted(two_sum([2, 7, 11, 15], 9)) == [0, 1]
assert sorted(two_sum([3, 2, 4], 6)) == [1, 2]

# %% [markdown]
# ### Question 7: Move Zeros to End
#
# **Difficulty:** Medium
# **Data structure:** Lists (in-place / two pointers)
#
# **Problem:** Given a list of integers, move all zeros to the end while preserving the relative order of non-zero elements. Modify the list in-place and return it.
#
# **Example Input:** `[0, 1, 0, 3, 12]`
# **Example Output:** `[1, 3, 12, 0, 0]`
#
# **Constraints:** 1 ≤ len(nums) ≤ 10^4
# **Expected Time Complexity:** O(n)

# %%
def move_zeros(nums: list) -> list:
    # Your code here (in-place)
    pass

# Test
arr = [0, 1, 0, 3, 12]
move_zeros(arr)
assert arr == [1, 3, 12, 0, 0]

# %% [markdown]
# ### Question 8: Maximum Sum of Contiguous Subarray (Kadane-style)
#
# **Difficulty:** Medium
# **Data structure:** Lists (single pass / simple DP idea)
#
# **Problem:** Given a list of integers (may contain negatives), find the largest sum of any contiguous subarray.
#
# **Example Input:** `[-2, 1, -3, 4, -1, 2, 1, -5, 4]`
# **Example Output:** `6` (subarray [4, -1, 2, 1])
#
# **Constraints:** 1 ≤ len(nums) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def max_subarray_sum(nums: list) -> int:
    # Your code here
    pass

# Test
assert max_subarray_sum([-2, 1, -3, 4, -1, 2, 1, -5, 4]) == 6
assert max_subarray_sum([1]) == 1

# %% [markdown]
# ### Question 9: Find All Duplicates in a List (1 to n)
#
# **Difficulty:** Medium
# **Data structure:** Lists (frequency counting / set)
#
# **Problem:** Given a list of integers where each value is in the range [1, n] and n = len(nums), return a list of all integers that appear exactly twice (or more). Each duplicate should appear once in the result.
#
# **Example Input:** `[4, 3, 2, 7, 8, 2, 3, 1]`
# **Example Output:** `[2, 3]` (or [3, 2] — order may vary)
#
# **Constraints:** 1 ≤ len(nums) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def find_duplicates(nums: list) -> list:
    # Your code here
    pass

# Test
result = find_duplicates([4, 3, 2, 7, 8, 2, 3, 1])
assert set(result) == {2, 3} and len(result) == 2

# %% [markdown]
# ### Question 10: Container With Most Water (Two Pointers)
#
# **Difficulty:** Medium
# **Data structure:** Lists (two pointers)
#
# **Problem:** Given a list of non-negative integers where each value represents the height of a vertical line, find two lines that form a container (with the x-axis) such that the container holds the most water. Return the maximum area.
#
# **Example Input:** `[1, 8, 6, 2, 5, 4, 8, 3, 7]`
# **Example Output:** `49`
#
# **Constraints:** 2 ≤ len(height) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def max_area(height: list) -> int:
    # Your code here
    pass

# Test
assert max_area([1, 8, 6, 2, 5, 4, 8, 3, 7]) == 49
assert max_area([1, 1]) == 1
