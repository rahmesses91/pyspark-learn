# %% [markdown]
# # SETS — Coding Interview Practice
#
# 10 algorithm-style questions (5 Easy, 5 Medium) focused on **sets**.
#
# Use the empty code cells to write your solution and run tests.

# %% [markdown]
# ---
# ## Easy (5 Questions)
# ---

# %% [markdown]
# ### Question 1: Remove Duplicates from a List
#
# **Difficulty:** Easy
# **Data structure:** Sets (deduplication)
#
# **Problem:** Given a list, return a new list containing each distinct element exactly once. Preserve the first occurrence order if possible (e.g. use set for membership, list for order).
#
# **Example Input:** `[1, 2, 2, 3, 1, 4, 3]`
# **Example Output:** `[1, 2, 3, 4]`
#
# **Constraints:** 0 ≤ len(arr) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def remove_duplicates(arr: list) -> list:
    # Your code here
    pass

# Test
assert remove_duplicates([1, 2, 2, 3, 1, 4, 3]) == [1, 2, 3, 4]

# %% [markdown]
# ### Question 2: Check if List Has Duplicates
#
# **Difficulty:** Easy
# **Data structure:** Sets
#
# **Problem:** Given a list, return True if any element appears at least twice, else False.
#
# **Example Input:** `[1, 2, 3, 1]`
# **Example Output:** `True`
#
# **Constraints:** 1 ≤ len(nums) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def has_duplicate(nums: list) -> bool:
    # Your code here
    pass

# Test
assert has_duplicate([1, 2, 3, 1]) is True
assert has_duplicate([1, 2, 3, 4]) is False

# %% [markdown]
# ### Question 3: Intersection of Two Lists
#
# **Difficulty:** Easy
# **Data structure:** Sets
#
# **Problem:** Given two lists, return a list of elements that appear in both. Each element should appear at most once in the result. Order does not matter.
#
# **Example Input:** `[1, 2, 3, 4]`, `[3, 4, 5, 6]`
# **Example Output:** `[3, 4]` (or [4, 3])
#
# **Constraints:** 0 ≤ len(list1), len(list2) ≤ 10^5
# **Expected Time Complexity:** O(n + m)

# %%
def intersection_two_lists(list1: list, list2: list) -> list:
    # Your code here
    pass

# Test
result = intersection_two_lists([1, 2, 3, 4], [3, 4, 5, 6])
assert set(result) == {3, 4} and len(result) == 2

# %% [markdown]
# ### Question 4: Union of Two Lists
#
# **Difficulty:** Easy
# **Data structure:** Sets
#
# **Problem:** Given two lists, return a list of all distinct elements that appear in either list. No duplicates in the result.
#
# **Example Input:** `[1, 2, 3]`, `[2, 3, 4]`
# **Example Output:** `[1, 2, 3, 4]` (order may vary)
#
# **Constraints:** 0 ≤ len(list1), len(list2) ≤ 10^5
# **Expected Time Complexity:** O(n + m)

# %%
def union_two_lists(list1: list, list2: list) -> list:
    # Your code here
    pass

# Test
result = union_two_lists([1, 2, 3], [2, 3, 4])
assert set(result) == {1, 2, 3, 4} and len(result) == 4

# %% [markdown]
# ### Question 5: Elements in First List But Not in Second
#
# **Difficulty:** Easy
# **Data structure:** Sets (difference)
#
# **Problem:** Given two lists, return a list of elements that are in the first list but not in the second. No duplicates in the result.
#
# **Example Input:** `[1, 2, 3, 4]`, `[2, 4, 5]`
# **Example Output:** `[1, 3]` (order may vary)
#
# **Constraints:** 0 ≤ len(list1), len(list2) ≤ 10^5
# **Expected Time Complexity:** O(n + m)

# %%
def in_first_not_second(list1: list, list2: list) -> list:
    # Your code here
    pass

# Test
result = in_first_not_second([1, 2, 3, 4], [2, 4, 5])
assert set(result) == {1, 3} and len(result) == 2

# %% [markdown]
# ---
# ## Medium (5 Questions)
# ---

# %% [markdown]
# ### Question 6: Find the Missing Number (1 to n)
#
# **Difficulty:** Medium
# **Data structure:** Sets (efficient lookup)
#
# **Problem:** Given a list containing n distinct numbers from the range [0, n] (so one number is missing), return the missing number.
#
# **Example Input:** `[3, 0, 1]`
# **Example Output:** `2`
#
# **Constraints:** n == len(nums), 1 ≤ n ≤ 10^4
# **Expected Time Complexity:** O(n)

# %%
def missing_number(nums: list) -> int:
    # Your code here
    pass

# Test
assert missing_number([3, 0, 1]) == 2
assert missing_number([0, 1]) == 2

# %% [markdown]
# ### Question 7: Find Unique Element in List Where All Others Repeat Twice
#
# **Difficulty:** Medium
# **Data structure:** Sets (or XOR trick)
#
# **Problem:** Every element in the list appears exactly twice except one. Find and return that single element.
#
# **Example Input:** `[4, 1, 2, 1, 2]`
# **Example Output:** `4`
#
# **Constraints:** 1 ≤ len(nums) ≤ 10^5, odd length
# **Expected Time Complexity:** O(n)

# %%
def single_number(nums: list):
    # Your code here
    pass

# Test
assert single_number([4, 1, 2, 1, 2]) == 4
assert single_number([2, 2, 1]) == 1

# %% [markdown]
# ### Question 8: Two Lists — Common and Unique
#
# **Difficulty:** Medium
# **Data structure:** Sets (intersection, difference)
#
# **Problem:** Given two lists, return a tuple (common, only_in_first, only_in_second) where each is a list of distinct elements.
#
# **Example Input:** `[1, 2, 3, 4]`, `[3, 4, 5, 6]`
# **Example Output:** `([3, 4], [1, 2], [5, 6])` (order within lists may vary)
#
# **Constraints:** 0 ≤ len(list1), len(list2) ≤ 10^5
# **Expected Time Complexity:** O(n + m)

# %%
def common_and_unique(list1: list, list2: list) -> tuple:
    # Your code here
    pass

# Test
common, only1, only2 = common_and_unique([1, 2, 3, 4], [3, 4, 5, 6])
assert set(common) == {3, 4} and set(only1) == {1, 2} and set(only2) == {5, 6}

# %% [markdown]
# ### Question 9: Jewels and Stones
#
# **Difficulty:** Medium
# **Data structure:** Sets (efficient membership)
#
# **Problem:** You have a string `jewels` (distinct character types) and a string `stones`. Return how many characters in `stones` are jewels.
#
# **Example Input:** `jewels = "aA"`, `stones = "aAAbbbb"`
# **Example Output:** `3`
#
# **Constraints:** 1 ≤ len(jewels), len(stones) ≤ 50
# **Expected Time Complexity:** O(len(jewels) + len(stones))

# %%
def num_jewels_in_stones(jewels: str, stones: str) -> int:
    # Your code here
    pass

# Test
assert num_jewels_in_stones("aA", "aAAbbbb") == 3
assert num_jewels_in_stones("z", "ZZ") == 0

# %% [markdown]
# ### Question 10: Happy Number (Set for Cycle Detection)
#
# **Difficulty:** Medium
# **Data structure:** Sets (deduplication / cycle detection)
#
# **Problem:** A number is happy if repeatedly replacing it by the sum of squares of its digits eventually reaches 1. If it loops forever without reaching 1, it is not happy. Given n, return True if n is happy, else False.
#
# **Example Input:** `19`
# **Example Output:** `True` (1²+9²=82 → 64+4=68 → ... → 1)
#
# **Constraints:** 1 ≤ n ≤ 2^31 - 1
# **Expected Time Complexity:** O(log n) per step, bounded by cycle length

# %%
def is_happy(n: int) -> bool:
    # Your code here
    pass

# Test
assert is_happy(19) is True
assert is_happy(2) is False
