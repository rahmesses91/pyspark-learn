# %% [markdown]
# # STRINGS — Coding Interview Practice
#
# 10 algorithm-style questions (5 Easy, 5 Medium) focused on **strings**.
#
# Use the empty code cells to write your solution and run tests.

# %% [markdown]
# ---
# ## Easy (5 Questions)
# ---

# %% [markdown]
# ### Question 1: Reverse a String
#
# **Difficulty:** Easy
# **Data structure:** Strings
#
# **Problem:** Given a string, return the string reversed. Do not use built-in `reversed()` or `[::-1]` in your solution logic (implement the reversal yourself, e.g. with a loop).
#
# **Example Input:** `"hello"`
# **Example Output:** `"olleh"`
#
# **Constraints:** 1 ≤ len(s) ≤ 10^4
# **Expected Time Complexity:** O(n)

# %%
def reverse_string(s: str) -> str:
    # Your code here
    pass

# Test
assert reverse_string("hello") == "olleh"
assert reverse_string("a") == "a"

# %% [markdown]
# ### Question 2: Count Vowels in a String
#
# **Difficulty:** Easy
# **Data structure:** Strings
#
# **Problem:** Given a string, count how many vowels (a, e, i, o, u) it contains. Treat uppercase and lowercase as the same.
#
# **Example Input:** `"Hello World"`
# **Example Output:** `3`
#
# **Constraints:** 1 ≤ len(s) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def count_vowels(s: str) -> int:
    # Your code here
    pass

# Test
assert count_vowels("Hello World") == 3
assert count_vowels("xyz") == 0

# %% [markdown]
# ### Question 3: Check if String is Palindrome
#
# **Difficulty:** Easy
# **Data structure:** Strings
#
# **Problem:** Given a string, return True if it reads the same forward and backward (ignoring case and non-alphanumeric characters). Otherwise return False.
#
# **Example Input:** `"A man, a plan, a canal: Panama"`
# **Example Output:** `True`
#
# **Constraints:** 1 ≤ len(s) ≤ 2×10^5
# **Expected Time Complexity:** O(n)

# %%
def is_palindrome(s: str) -> bool:
    # Your code here
    pass

# Test
assert is_palindrome("A man, a plan, a canal: Panama") is True
assert is_palindrome("race a car") is False

# %% [markdown]
# ### Question 4: Capitalize First Letter of Each Word
#
# **Difficulty:** Easy
# **Data structure:** Strings
#
# **Problem:** Given a string of words separated by spaces, return the string with the first letter of each word capitalized. Assume words are separated by single spaces.
#
# **Example Input:** `"hello world python"`
# **Example Output:** `"Hello World Python"`
#
# **Constraints:** 1 ≤ len(s) ≤ 10^4
# **Expected Time Complexity:** O(n)

# %%
def capitalize_words(s: str) -> str:
    # Your code here
    pass

# Test
assert capitalize_words("hello world python") == "Hello World Python"

# %% [markdown]
# ### Question 5: Remove All Occurrences of a Character
#
# **Difficulty:** Easy
# **Data structure:** Strings
#
# **Problem:** Given a string and a character, return a new string with all occurrences of that character removed.
#
# **Example Input:** `s = "hello world"`, `char = "l"`
# **Example Output:** `"heo word"`
#
# **Constraints:** 1 ≤ len(s) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def remove_char(s: str, char: str) -> str:
    # Your code here
    pass

# Test
assert remove_char("hello world", "l") == "heo word"
assert remove_char("aaa", "a") == ""

# %% [markdown]
# ---
# ## Medium (5 Questions)
# ---

# %% [markdown]
# ### Question 6: First Non-Repeating Character
#
# **Difficulty:** Medium
# **Data structure:** Strings (frequency counting)
#
# **Problem:** Given a string, return the first character that does not repeat anywhere in the string. If all characters repeat, return an empty string or None.
#
# **Example Input:** `"leetcode"`
# **Example Output:** `"l"`
#
# **Constraints:** 1 ≤ len(s) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def first_non_repeating(s: str):
    # Your code here
    pass

# Test
assert first_non_repeating("leetcode") == "l"
assert first_non_repeating("aabbcc") in ("", None)

# %% [markdown]
# ### Question 7: Longest Substring Without Repeating Characters (Sliding Window)
#
# **Difficulty:** Medium
# **Data structure:** Strings (sliding window / set or dict for seen chars)
#
# **Problem:** Given a string, find the length of the longest substring without repeating characters.
#
# **Example Input:** `"abcabcbb"`
# **Example Output:** `3` (e.g. "abc")
#
# **Constraints:** 0 ≤ len(s) ≤ 5×10^4
# **Expected Time Complexity:** O(n)

# %%
def length_of_longest_substring(s: str) -> int:
    # Your code here
    pass

# Test
assert length_of_longest_substring("abcabcbb") == 3
assert length_of_longest_substring("bbbbb") == 1

# %% [markdown]
# ### Question 8: Valid Anagram
#
# **Difficulty:** Medium
# **Data structure:** Strings (frequency counting)
#
# **Problem:** Given two strings, return True if one is an anagram of the other (same characters, same frequencies, order may differ).
#
# **Example Input:** `s1 = "anagram"`, `s2 = "nagaram"`
# **Example Output:** `True`
#
# **Constraints:** 1 ≤ len(s1), len(s2) ≤ 5×10^4
# **Expected Time Complexity:** O(n)

# %%
def is_anagram(s1: str, s2: str) -> bool:
    # Your code here
    pass

# Test
assert is_anagram("anagram", "nagaram") is True
assert is_anagram("rat", "car") is False

# %% [markdown]
# ### Question 9: String Compression (Run-Length Style)
#
# **Difficulty:** Medium
# **Data structure:** Strings (parsing / traversal)
#
# **Problem:** Given a string, compress it so that consecutive duplicate characters are replaced by the character followed by its count. If count is 1, omit the number. Return the compressed string.
#
# **Example Input:** `"aabcccccaaa"`
# **Example Output:** `"a2bc5a3"`
#
# **Constraints:** 1 ≤ len(s) ≤ 10^4
# **Expected Time Complexity:** O(n)

# %%
def compress_string(s: str) -> str:
    # Your code here
    pass

# Test
assert compress_string("aabcccccaaa") == "a2bc5a3"
assert compress_string("abc") == "abc"

# %% [markdown]
# ### Question 10: Find All Anagrams in a String (Sliding Window)
#
# **Difficulty:** Medium
# **Data structure:** Strings (sliding window + frequency counting)
#
# **Problem:** Given a string `s` and a string `p`, return a list of start indices of all substrings in `s` that are anagrams of `p`.
#
# **Example Input:** `s = "cbaebabacd"`, `p = "abc"`
# **Example Output:** `[0, 6]`
#
# **Constraints:** 1 ≤ len(p) ≤ len(s) ≤ 3×10^4
# **Expected Time Complexity:** O(n)

# %%
def find_anagram_indices(s: str, p: str) -> list:
    # Your code here
    pass

# Test
assert find_anagram_indices("cbaebabacd", "abc") == [0, 6]
assert find_anagram_indices("abab", "ab") == [0, 1, 2]
