# %% [markdown]
# # DICTIONARIES — Coding Interview Practice
#
# 10 algorithm-style questions (5 Easy, 5 Medium) focused on **dictionaries**.
#
# Use the empty code cells to write your solution and run tests.

# %% [markdown]
# ---
# ## Easy (5 Questions)
# ---

# %% [markdown]
# ### Question 1: Count Character Frequencies
#
# **Difficulty:** Easy
# **Data structure:** Dictionaries (frequency counting)
#
# **Problem:** Given a string, return a dictionary mapping each character to how many times it appears.
#
# **Example Input:** `"hello"`
# **Example Output:** `{"h": 1, "e": 1, "l": 2, "o": 1}`
#
# **Constraints:** 1 ≤ len(s) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def char_frequency(s: str) -> dict:
    # Your code here
    pass

# Test
assert char_frequency("hello") == {"h": 1, "e": 1, "l": 2, "o": 1}

# %% [markdown]
# ### Question 2: Count Element Frequencies in a List
#
# **Difficulty:** Easy
# **Data structure:** Dictionaries (frequency counting)
#
# **Problem:** Given a list, return a dictionary mapping each element to its count.
#
# **Example Input:** `[1, 2, 2, 3, 2, 1]`
# **Example Output:** `{1: 2, 2: 3, 3: 1}`
#
# **Constraints:** 0 ≤ len(arr) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def count_frequency(arr: list) -> dict:
    # Your code here
    pass

# Test
assert count_frequency([1, 2, 2, 3, 2, 1]) == {1: 2, 2: 3, 3: 1}

# %% [markdown]
# ### Question 3: Group Words by First Letter
#
# **Difficulty:** Easy
# **Data structure:** Dictionaries (grouping)
#
# **Problem:** Given a list of words, return a dictionary where keys are first letters and values are lists of words starting with that letter.
#
# **Example Input:** `["apple", "banana", "apricot", "blue"]`
# **Example Output:** `{"a": ["apple", "apricot"], "b": ["banana", "blue"]}`
#
# **Constraints:** 0 ≤ len(words) ≤ 10^4, each word non-empty
# **Expected Time Complexity:** O(n × word length)

# %%
def group_by_first_letter(words: list) -> dict:
    # Your code here
    pass

# Test
result = group_by_first_letter(["apple", "banana", "apricot", "blue"])
assert set(result["a"]) == {"apple", "apricot"} and set(result["b"]) == {"banana", "blue"}

# %% [markdown]
# ### Question 4: Invert a Dictionary (Values Become Keys)
#
# **Difficulty:** Easy
# **Data structure:** Dictionaries
#
# **Problem:** Given a dictionary, return a new dictionary where original values become keys and original keys become values. If multiple keys share the same value, map that value to a list of those keys.
#
# **Example Input:** `{"a": 1, "b": 2, "c": 1}`
# **Example Output:** `{1: ["a", "c"], 2: ["b"]}`
#
# **Constraints:** 0 ≤ len(d) ≤ 10^4
# **Expected Time Complexity:** O(n)

# %%
def invert_dict(d: dict) -> dict:
    # Your code here
    pass

# Test
result = invert_dict({"a": 1, "b": 2, "c": 1})
assert set(result[1]) == {"a", "c"} and result[2] == ["b"]

# %% [markdown]
# ### Question 5: Merge Two Dictionaries (Sum Values for Common Keys)
#
# **Difficulty:** Easy
# **Data structure:** Dictionaries
#
# **Problem:** Given two dictionaries with numeric values, return a new dictionary that merges them. For keys present in both, sum the values; otherwise keep the single value.
#
# **Example Input:** `{"a": 1, "b": 2}`, `{"b": 3, "c": 4}`
# **Example Output:** `{"a": 1, "b": 5, "c": 4}`
#
# **Constraints:** 0 ≤ len(d1), len(d2) ≤ 10^4
# **Expected Time Complexity:** O(n + m)

# %%
def merge_dicts_sum(d1: dict, d2: dict) -> dict:
    # Your code here
    pass

# Test
assert merge_dicts_sum({"a": 1, "b": 2}, {"b": 3, "c": 4}) == {"a": 1, "b": 5, "c": 4}

# %% [markdown]
# ---
# ## Medium (5 Questions)
# ---

# %% [markdown]
# ### Question 6: Two Sum (Return Indices)
#
# **Difficulty:** Medium
# **Data structure:** Dictionaries (efficient lookup)
#
# **Problem:** Given a list of integers and a target, return indices of two numbers that add up to target. Assume exactly one solution. Use a dictionary for O(n) lookup.
#
# **Example Input:** `nums = [2, 7, 11, 15]`, `target = 9`
# **Example Output:** `[0, 1]`
#
# **Constraints:** 2 ≤ len(nums) ≤ 10^4
# **Expected Time Complexity:** O(n)

# %%
def two_sum(nums: list, target: int) -> list:
    # Your code here (use dict)
    pass

# Test
assert sorted(two_sum([2, 7, 11, 15], 9)) == [0, 1]

# %% [markdown]
# ### Question 7: Group Anagrams
#
# **Difficulty:** Medium
# **Data structure:** Dictionaries (grouping by key)
#
# **Problem:** Given a list of strings, group them into lists such that strings in the same list are anagrams of each other. Return a list of these groups. Use a canonical key (e.g. sorted tuple of chars) for grouping.
#
# **Example Input:** `["eat", "tea", "tan", "ate", "nat", "bat"]`
# **Example Output:** `[["eat", "tea", "ate"], ["tan", "nat"], ["bat"]]` (order of groups and within groups may vary)
#
# **Constraints:** 1 ≤ len(strs) ≤ 10^4
# **Expected Time Complexity:** O(n × k log k) for n strings of max length k

# %%
def group_anagrams(strs: list) -> list:
    # Your code here
    pass

# Test
result = group_anagrams(["eat", "tea", "tan", "ate", "nat", "bat"])
result_sets = [set(g) for g in result]
assert {"eat", "tea", "ate"} in result_sets  # one group
assert len(result) == 3

# %% [markdown]
# ### Question 8: First Non-Repeating Character (Index)
#
# **Difficulty:** Medium
# **Data structure:** Dictionaries (frequency then scan)
#
# **Problem:** Given a string, return the index of the first character that appears exactly once. If none, return -1.
#
# **Example Input:** `"leetcode"`
# **Example Output:** `0` ("l")
#
# **Constraints:** 1 ≤ len(s) ≤ 10^5
# **Expected Time Complexity:** O(n)

# %%
def first_unique_char_index(s: str) -> int:
    # Your code here
    pass

# Test
assert first_unique_char_index("leetcode") == 0
assert first_unique_char_index("aabb") == -1

# %% [markdown]
# ### Question 9: Ransom Note
#
# **Difficulty:** Medium
# **Data structure:** Dictionaries (frequency counting)
#
# **Problem:** Given two strings `ransom_note` and `magazine`, return True if you can build `ransom_note` by using characters from `magazine` (each character in magazine can be used at most once).
#
# **Example Input:** `ransom_note = "a"`, `magazine = "b"`
# **Example Output:** `False`
# **Example Input 2:** `ransom_note = "aa"`, `magazine = "aab"`
# **Example Output 2:** `True`
#
# **Constraints:** 1 ≤ len(ransom_note), len(magazine) ≤ 10^5
# **Expected Time Complexity:** O(n + m)

# %%
def can_construct(ransom_note: str, magazine: str) -> bool:
    # Your code here
    pass

# Test
assert can_construct("a", "b") is False
assert can_construct("aa", "aab") is True

# %% [markdown]
# ### Question 10: Top K Frequent Elements
#
# **Difficulty:** Medium
# **Data structure:** Dictionaries (frequency counting)
#
# **Problem:** Given a list of integers and an integer k, return the k most frequent elements. You may return the answer in any order. Use a dictionary to count frequency; then sort or use a simple approach to get top k (no heap required).
#
# **Example Input:** `nums = [1, 1, 1, 2, 2, 3]`, `k = 2`
# **Example Output:** `[1, 2]` (or [2, 1])
#
# **Constraints:** 1 ≤ len(nums) ≤ 10^5, 1 ≤ k ≤ number of distinct elements
# **Expected Time Complexity:** O(n log n) or O(n) with bucket approach

# %%
def top_k_frequent(nums: list, k: int) -> list:
    # Your code here
    pass

# Test
result = top_k_frequent([1, 1, 1, 2, 2, 3], 2)
assert set(result) == {1, 2} and len(result) == 2
